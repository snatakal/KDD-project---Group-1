# %%
import pandas as pd
import warnings
import os
warnings.filterwarnings('ignore')

# %%
parent_dir = os.path.dirname(os.getcwd())
data_path = os.path.join(parent_dir, 'data', 'dataset')
out_path = os.path.join(parent_dir, 'data', 'train')

# %%
dataset = pd.read_csv(os.path.join(data_path, 'dataset.csv'))
champ_role_kda = pd.read_csv(os.path.join(data_path, 'champ_role_kda.csv'))
champ_role_wr = pd.read_csv(os.path.join(data_path, 'champ_role_wr.csv'))
champ_wr = pd.read_csv(os.path.join(data_path, 'champ_wr.csv'))

# %%
dataset.head(10)
# Out:
#    GOLDEARNED  TOTALMINIONSKILLED    WIN  KILLS  ASSISTS  DEATHS  CHAMPION  \
# 0       14425                 194  False     14        5       7  Kassadin
# 1       12920                 177   True      3       13       6     Fiora
# 2       13483                 221  False      7        3       6      Yone
# 3       11375                 167   True      4       15       7     Corki
# 4       11320                 197  False      5       10      12     Kaisa
# 5       18875                 217   True     18        8       5    Samira
# 6        8098                  31  False      3       16      13  Nautilus
# 7        9046                  33   True      3       17      10  Pantheon
# 8       11187                  22  False      8       10       9   Evelynn
# 9       16412                  50   True     19        6       9      Kayn
#
#    VISIONSCORE                                              PUUID  \
# 0           17  phduyQLB8gBjUerFwiVOtyLLHE9jxw7Jq7dwab_CtRddAv...
# ...

# %%
champ_role_combinations = pd.DataFrame(extracted['CHAMPION'].str.cat(extracted[['ROLE']], sep='_'))
