# %%
import pandas as pd
import warnings
import os
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
parent_dir = os.path.dirname(os.getcwd())
data_path = os.path.join(parent_dir, 'data', 'dataset')

# %%
dataset = pd.read_csv(os.path.join(data_path, 'dataset.csv'))
print(dataset.shape)
# Out:
# (1312248, 15)

# %%
# unique players
counts = dataset[['PUUID']].value_counts().reset_index(name="count")
print("Total players: ", len(counts))
plt.figure(figsize=(20,10))
sns.countplot(counts['count'])
plt.show()
# Out:
# Total players:  322153

# %%
# unique players with more than 20 games
counts = dataset[['PUUID']].value_counts().reset_index(name="count").query("count > 20")
print("Total players: ", len(counts))
plt.figure(figsize=(20,10))
sns.countplot(counts['count'])
plt.show()
# Out:
# Total players:  11510

# %%
# players in each role
role_counts = dataset.groupby(['PUUID', "ROLE"]).size().reset_index(name="count")
print("Total players x roles: ", len(role_counts))
print("Total unique players: ", role_counts.PUUID.nunique())
# Out:
# Total players x roles:  452355
# Total unique players:  322153

# %%
# players with min 15 and max 60 games in each role
role_counts = role_counts.query('count > 14').query('count < 46')
print("Total players x roles: ", len(role_counts))
print("Total unique players: ", role_counts.PUUID.nunique())
plt.figure(figsize=(20,10))
sns.countplot(role_counts['count'])
plt.show()
# Out:
# Total players x roles:  12507
# Total unique players:  11980

# %%
extracted = dataset.copy()

# %%
extracted['player_role'] = extracted['PUUID'].str.cat(extracted[['ROLE']], sep='_')
extracted['player_role'].nunique()
# Out:
# 452355

# %%
player_role_counts = extracted.player_role.value_counts().reset_index(name = 'count')
player_role_counts = player_role_counts.query('count > 14').query('count < 46')

# %%
extracted = extracted[extracted.player_role.isin(player_role_counts['index'])]
extracted.player_role.nunique()
# Out:
# 12507

# %%
extracted
# Out:
#          GOLDEARNED  TOTALMINIONSKILLED    WIN  KILLS  ASSISTS  DEATHS  \
# 5             18875                 217   True     18        8       5
# 12            18806                 254   True     10       17       7
# 25            10449                  24   True      8       16       3
# 29            10681                 157   True      3       12       5
# 31            13584                 148   True     13        9       8
# ...             ...                 ...    ...    ...      ...     ...
# 1312215        9460                  32   True      2       15       7
# 1312218        6681                 110  False      1        3      13
# 1312224        7475                  48  False      4        6       8
# 1312226        8649                  42  False      3        6       7
# 1312236       13315                 199  False      8        4       5
#
#              CHAMPION  VISIONSCORE  \
# 5              Samira           33
# 12               Yone           19
# 25       FiddleSticks           26
# 29        AurelionSol           13
# 31            Caitlyn           10
# ...               ...          ...
# 1312215      Nautilus           77
# 1312218         Fiora           12
# 1312224         Neeko           47
# 1312226          Ekko            5
# 1312236        Darius           17
#
#                                                      PUUID  \
# 5        qznX9K4_EITdadLJBTrTj22x_27pqrpuA6c1aTq1-3AeYq...
# 12       q-kCvxUxu5fAVilpeeKTWG2OYldWX3n8akfNGXKt9moNOi...
# 25       x8Bft0cHjvbPCs3NV86sZkPUQMvDNcF7sXYjnXmaJyJwhY...
# 29       XqpW60qiVFGt2Q8tczYj4-_-nPN_R441-2xkYDaVdJml9q...
# 31       MoGHCpW2fpHQZMyXsonT8P_Maqjxy10SprzQTBkh4UEf8g...
# ...                                                    ...
# 1312215  FrHbp1XNgUIj24OvpQNQvpytVMdbldzl5P_-sJRiOBK5zP...
# 1312218  rSgBYOIIhRedCWP8HfR4okLLndVGIkFzQBudW5f6Id_qRH...
# 1312224  WMUn9-RFcfOlmQ96JMq7rUefcVr2NeCscrgfPrsIzicuAn...
# 1312226  1DGqHZrWv8Ekklozh7V_nwAwfVe5EoKcESGD7AUvRDLhd0...
# 1312236  gI9CQ5voLS-LQEvwrMgX8weeABjzoxcLbTF5RaZQ4xhax5...
#
#          TOTALDAMAGEDEALTTOCHAMPIONS      SUMMONERNAME     GAMEVERSION REGION  \
# 5                              29005        just Logic  11.14.384.6677    TR1
# 12                             36232   Im Leon Kennedy  11.15.389.2308    LA1
# 25                             18389             Yınıs  11.13.382.1241    TR1
# 29                             13885    Crazy Aurelion  11.13.382.1241    TR1
# 31                             34332        Unforgiven  11.13.382.1241    TR1
# ...                              ...               ...             ...    ...
# 1312215                        13364        EliteJoint  11.13.382.1241   EUW1
# 1312218                        16815  TurningBackTime1  11.13.382.1241   EUW1
# 1312224                        12903         AquaCloak  11.13.382.1241   EUW1
# 1312226                         6997   imawasteofspace  11.13.382.1241   EUW1
# 1312236                        29882          xcessive   11.9.372.2066   EUW1
#
#                 MATCH_ID     ROLE  \
# 5         1201957752_TR1   bottom
# 12        1118868552_LA1   middle
# 25        1201281015_TR1   jungle
# 29        1201191468_TR1   middle
# 31        1201191468_TR1   bottom
# ...                  ...      ...
# 1312215  5354922482_EUW1  utility
# 1312218  5354839245_EUW1      top
# 1312224  5354839245_EUW1  utility
# 1312226  5354839245_EUW1   jungle
# 1312236  5262352897_EUW1      top
#
#                                                player_role
# 5        qznX9K4_EITdadLJBTrTj22x_27pqrpuA6c1aTq1-3AeYq...
# 12       q-kCvxUxu5fAVilpeeKTWG2OYldWX3n8akfNGXKt9moNOi...
# 25       x8Bft0cHjvbPCs3NV86sZkPUQMvDNcF7sXYjnXmaJyJwhY...
# 29       XqpW60qiVFGt2Q8tczYj4-_-nPN_R441-2xkYDaVdJml9q...
# 31       MoGHCpW2fpHQZMyXsonT8P_Maqjxy10SprzQTBkh4UEf8g...
# ...                                                    ...
# 1312215  FrHbp1XNgUIj24OvpQNQvpytVMdbldzl5P_-sJRiOBK5zP...
# 1312218  rSgBYOIIhRedCWP8HfR4okLLndVGIkFzQBudW5f6Id_qRH...
# 1312224  WMUn9-RFcfOlmQ96JMq7rUefcVr2NeCscrgfPrsIzicuAn...
# 1312226  1DGqHZrWv8Ekklozh7V_nwAwfVe5EoKcESGD7AUvRDLhd0...
# 1312236  gI9CQ5voLS-LQEvwrMgX8weeABjzoxcLbTF5RaZQ4xhax5...
#
# [294057 rows x 16 columns]

# %%
match_counts = dataset.MATCH_ID.value_counts().reset_index(name = 'count')
match_counts = match_counts.query('count == 10')
match_counts
# Out:
#                   index  count
# 0        1201957752_TR1     10
# 1        1105779563_LA1     10
# 2        2326246890_BR1     10
# 3        2326330848_BR1     10
# 4        2326635837_BR1     10
# ...                 ...    ...
# 127403   1093218191_LA1     10
# 127404  5312300925_EUW1     10
# 127405   2297106099_BR1     10
# 127406  5262064940_EUW1     10
# 127407   1202382044_TR1     10
#
# [127408 rows x 2 columns]
